# %%
import pandas as pd

# %%
master_file = pd.read_csv("CoilData.csv")
master_file.head()
# Out:
#      coil  furnace Number analyse  Hardness_1  Hardness_2   Width  \
# 0  396378               1   K371        10003         101  1302.1
# 1  396376               3   K371        10123         101  1282.3
# 2  396377               4   K321        10040         102  1297.4
# 3  396379               3   K371        10243         102  1295.2
# 4  396380               4   K321        10012         100  1293.3
#
#    Temperature before finishing mill  Temperature after finishing mill  \
# 0                               1147                               921
# 1                               1150                               920
# 2                               1183                               933
# 3                               1165                               910
# 4                               1192                               909
#
#    Thickness Thickness profile  ...    p    s   al   ma  b   n  ti   cr  va  \
# ...

# %%
master_coil_list = []
for coil_number in master_file.coil:
    master_coil_list.append(coil_number)
                            
master_coil_list
# Out:
# [396378,
#  396376,
#  396377,
#  396379,
#  396380,
#  396381,
#  396382,
#  396383,
#  396384,
#  396385,
#  396386,
#  396387,
#  396388,
#  396389,
#  396390,
#  396391,
#  396392,
#  396393,
#  396394,
#  396395,
#  396396,
#  396397,
#  396398,
#  396399,
#  396400,
#  396401,
#  396402,
#  396403,
#  396404,
#  396405,
#  396406,
#  396407,
#  396408,
#  396409,
#  396410,
#  396411,
#  396412,
#  396413,
#  396414,
#  396415,
#  396416,
#  396417,
#  396418,
#  396419,
#  396420,
#  396421,
#  396422,
#  396423,
#  396424,
#  396425,
#  396426,
#  396427,
#  396428,
#  396429,
#  396430,
#  396431,
#  396432,
#  396433,
#  396434,
#  396435,
#  396436,
#  396437,
#  396438,
#  396440,
#  396441,
#  396442,
#  396443,
#  396444,
#  396445,
#  396447,
#  396448,
#  396449,
#  396450,
#  396451,
#  396452,
#  396453,
#  396454,
#  396455,
#  396456,
#  396457,
#  396458,
#  396459,
#  396460,
#  396461,
#  396462,
#  396463,
#  396464,
#  396465,
#  396466,
#  396467,
# ...

# %%
len(master_coil_list)
# Out:
# 57094

# %%
compare_df = pd.DataFrame()

# %%
master_coil = pd.Series(master_coil_list)

# %%
compare_df['master_coil_number'] = master_coil

# %%
compare_df
# Out:
#        master_coil_number
# 0                  396378
# 1                  396376
# 2                  396377
# 3                  396379
# 4                  396380
# ...                   ...
# 57089               20814
# 57090               20815
# 57091               20816
# 57092               20817
# 57093               20818
#
# [57094 rows x 1 columns]

# %%
import glob

# %%
path = r"C:\Users\Fidrmuc\Downloads\SignalExport\SignalExport"
all_files = glob.glob(path + "/*.csv")

# %%
signal_coil_folder = []
for filename in all_files:
    coilnum=filename.split("\\")[-1]
    coil_num = coilnum.split(".")[-2]
    coil_let = coil_num.split("B")[-2]
    signal_coil_folder.append(coil_let)

signal_coil_folder
# Out:
# ['10058',
#  '10058',
#  '10059',
#  '10059',
#  '10060',
#  '10060',
#  '10061',
#  '10061',
#  '10062',
#  '10062',
#  '10063',
#  '10063',
#  '10064',
#  '10064',
#  '10065',
#  '10065',
#  '10066',
#  '10066',
#  '10067',
#  '10067',
#  '10068',
#  '10068',
#  '10069',
#  '10069',
#  '10070',
#  '10070',
#  '10071',
#  '10071',
#  '10072',
#  '10072',
#  '10073',
#  '10073',
#  '10074',
#  '10074',
#  '10075',
#  '10075',
#  '10076',
#  '10076',
#  '10077',
#  '10077',
#  '10078',
#  '10078',
#  '10079',
#  '10079',
#  '10080',
#  '10080',
#  '10081',
#  '10081',
#  '10082',
#  '10082',
#  '10083',
#  '10083',
#  '10084',
#  '10084',
#  '10085',
#  '10085',
#  '10086',
#  '10086',
#  '10087',
#  '10087',
#  '10088',
#  '10088',
#  '10089',
#  '10089',
#  '10090',
#  '10090',
#  '10091',
#  '10091',
#  '10092',
#  '10092',
#  '10093',
#  '10093',
#  '10094',
#  '10094',
#  '10095',
#  '10095',
#  '10096',
#  '10096',
#  '10097',
#  '10097',
#  '10098',
#  '10098',
#  '10099',
# ...

# %%
len(signal_coil_folder)
# Out:
# 113540

# %%
signal_files = pd.Series(signal_coil_folder)

# %%
compare_df['signal_coil_number'] = signal_files

# %%
compare_df.head()
# Out:
#    master_coil_number signal_coil_number
# 0              396378              10058
# 1              396376              10058
# 2              396377              10059
# 3              396379              10059
# 4              396380              10060

# %%
len(signal_coil_folder) - len(master_coil)
# Out:
# 56446

# %%
dif = len(compare_df.master_coil_number) - len(compare_df.signal_coil_number)
dif
# Out:
# 0

# %%
len(compare_df.signal_coil_number)
# Out:
# 57094

# %%
len(compare_df.master_coil_number)
# Out:
# 57094
